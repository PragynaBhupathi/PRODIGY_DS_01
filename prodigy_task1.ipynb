# %% [markdown]
# <a href="https://colab.research.google.com/github/PragynaBhupathi/PRODIGY_DS_01/blob/main/prodigy_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Replace with the correct file path
file_path = '/content/API_SP.POP.TOTL_DS2_en_csv_v2_5871594.csv'

# Load the CSV file
df = pd.read_csv(file_path, header=4)  # Assuming the headers start at row 5 (index 4)

# %%
df.head()
# Out:
#   Africa Western and Central  AFW  Population, total  SP.POP.TOTL    97256290  \
# 0                     Angola  AGO  Population, total  SP.POP.TOTL   5357195.0
# 1                    Albania  ALB  Population, total  SP.POP.TOTL   1608800.0
# 2                    Andorra  AND  Population, total  SP.POP.TOTL      9443.0
# 3                 Arab World  ARB  Population, total  SP.POP.TOTL  93359407.0
# 4       United Arab Emirates  ARE  Population, total  SP.POP.TOTL    133426.0
#
#      99314028   101445032    103667517    105959979    108336203  ...  \
# 0   5441333.0   5521400.0    5599827.0    5673199.0    5736582.0  ...
# 1   1659800.0   1711319.0    1762621.0    1814135.0    1864791.0  ...
# 2     10216.0     11014.0      11839.0      12690.0      13563.0  ...
# 3  95760348.0  98268683.0  100892507.0  103618568.0  106444103.0  ...
# 4    140984.0    148877.0     157006.0     165305.0     173797.0  ...
#
#      387204553    397855507    408690375    419778384    431138704  \
# ...

# %%
df.describe()
# Out:
#            97256290      99314028     101445032     103667517     105959979  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.181652e+08  1.197776e+08  1.219584e+08  1.246580e+08  1.273793e+08
# std    3.722500e+08  3.768287e+08  3.835941e+08  3.923557e+08  4.011597e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.708088e+06  3.816540e+06  3.931214e+06  4.033994e+06  4.112910e+06
# 75%    2.540843e+07  2.617425e+07  2.694532e+07  2.772484e+07  2.849151e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#           108336203     110798486     113319950     115921723     118615741  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.301391e+08  1.330157e+08  1.358899e+08  1.388445e+08  1.419048e+08
# ...

# %%
df.tail()
# Out:
#     Africa Western and Central  AFW  Population, total  SP.POP.TOTL  \
# 257                     Kosovo  XKX  Population, total  SP.POP.TOTL
# 258                Yemen, Rep.  YEM  Population, total  SP.POP.TOTL
# 259               South Africa  ZAF  Population, total  SP.POP.TOTL
# 260                     Zambia  ZMB  Population, total  SP.POP.TOTL
# 261                   Zimbabwe  ZWE  Population, total  SP.POP.TOTL
#
#        97256290    99314028   101445032   103667517   105959979   108336203  \
# 257    947000.0    966000.0    994000.0   1022000.0   1050000.0   1078000.0
# 258   5542459.0   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0
# 259  16520441.0  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0
# 260   3119430.0   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0
# 261   3806310.0   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0
#
#      ...   387204553   397855507   408690375   419778384   431138704  \
# ...

# %%
df.shape
# Out:
# (262, 67)

# %%
df.columns
# Out:
# Index(['Africa Western and Central', 'AFW', 'Population, total', 'SP.POP.TOTL',
#        '97256290', '99314028', '101445032', '103667517', '105959979',
#        '108336203', '110798486', '113319950', '115921723', '118615741',
#        '121424797', '124336039', '127364044', '130563107', '133953892',
#        '137548613', '141258400', '145122851', '149206663', '153459665',
#        '157825609', '162323313', '167023385', '171566640', '176054495',
#        '180817312', '185720244', '190759952', '195969722', '201392200',
#        '206739024', '212172888', '217966101', '223788766', '229675775',
#        '235861484', '242200260', '248713095', '255482918', '262397030',
#        '269611898', '277160097', '284952322', '292977949', '301265247',
#        '309824829', '318601484', '327612838', '336893835', '346475221',
#        '356337762', '366489204', '376797999', '387204553', '397855507',
#        '408690375', '419778384', '431138704', '442646825', '454306063',
# ...

# %%
df.dtypes
# Out:
# Africa Western and Central     object
# AFW                            object
# Population, total              object
# SP.POP.TOTL                    object
# 97256290                      float64
#                                ...
# 442646825                     float64
# 454306063                     float64
# 466189102                     float64
# 478185907                     float64
# 490330870                     float64
# Length: 67, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 67 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Africa Western and Central  262 non-null    object
#  1   AFW                         262 non-null    object
#  2   Population, total           262 non-null    object
#  3   SP.POP.TOTL                 262 non-null    object
#  4   97256290                    260 non-null    float64
#  5   99314028                    260 non-null    float64
#  6   101445032                   260 non-null    float64
#  7   103667517                   260 non-null    float64
#  8   105959979                   260 non-null    float64
#  9   108336203                   260 non-null    float64
#  10  110798486                   260 non-null    float64
#  11  113319950                   260 non-null    float64
#  12  115921723                   260 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().any()
# Out:
# np.True_

# %%
df = df.fillna(method = "ffill")
df.head()
# Out:
# <ipython-input-16-b8f82a5e5a02>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = "ffill")
#   Africa Western and Central  AFW  Population, total  SP.POP.TOTL    97256290  \
# 0                     Angola  AGO  Population, total  SP.POP.TOTL   5357195.0
# 1                    Albania  ALB  Population, total  SP.POP.TOTL   1608800.0
# 2                    Andorra  AND  Population, total  SP.POP.TOTL      9443.0
# 3                 Arab World  ARB  Population, total  SP.POP.TOTL  93359407.0
# 4       United Arab Emirates  ARE  Population, total  SP.POP.TOTL    133426.0
#
#      99314028   101445032    103667517    105959979    108336203  ...  \
# 0   5441333.0   5521400.0    5599827.0    5673199.0    5736582.0  ...
# 1   1659800.0   1711319.0    1762621.0    1814135.0    1864791.0  ...
# 2     10216.0     11014.0      11839.0      12690.0      13563.0  ...
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Africa Western and Central', 'AFW', 'Population, total', 'SP.POP.TOTL', '97256290', '99314028', '101445032', '103667517', '105959979', '108336203', '110798486', '113319950', '115921723', '118615741', '121424797', '124336039', '127364044', '130563107', '133953892', '137548613', '141258400', '145122851', '149206663', '153459665', '157825609', '162323313', '167023385', '171566640', '176054495', '180817312', '185720244', '190759952', '195969722', '201392200', '206739024', '212172888', '217966101', '223788766', '229675775', '235861484', '242200260', '248713095', '255482918', '262397030', '269611898', '277160097', '284952322', '292977949', '301265247', '309824829', '318601484', '327612838', '336893835', '346475221', '356337762', '366489204', '376797999', '387204553', '397855507', '408690375', '419778384', '431138704', '442646825', '454306063', '466189102', '478185907', '490330870']

# %%
# Replace with the actual column name from your DataFrame.
# You can verify the exact name by printing:
# print(df.columns)
actual_column_name = 'Africa Western and Central'
df[actual_column_name].unique()
# Out:
# array(['Angola', 'Albania', 'Andorra', 'Arab World',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria',
#        'East Asia & Pacific (excluding high income)',
# ...

# %%
df['AFW'].unique()
# Out:
# array(['AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG',
#        'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD', 'BGR',
#        'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB',
#        'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CEB', 'CHE', 'CHI', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI',
#        'CSS', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA',
#        'DNK', 'DOM', 'DZA', 'EAP', 'EAR', 'EAS', 'ECA', 'ECS', 'ECU',
#        'EGY', 'EMU', 'ERI', 'ESP', 'EST', 'ETH', 'EUU', 'FCS', 'FIN',
#        'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB',
#        'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM',
#        'GUY', 'HIC', 'HKG', 'HND', 'HPC', 'HRV', 'HTI', 'HUN', 'IBD',
#        'IBT', 'IDA', 'IDB', 'IDN', 'IDX', 'IMN', 'IND', 'INX', 'IRL',
#        'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ',
# ...

# %%
# Access the column using the exact column name, including any trailing spaces/tabs
df['Population, total'].unique()
# Out:
# array(['Population, total'], dtype=object)

# %%
df['SP.POP.TOTL'].unique()
# Out:
# array(['SP.POP.TOTL'], dtype=object)

# %%
df.drop(['Population, total','SP.POP.TOTL','AFW'],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Africa Western and Central', '97256290', '99314028', '101445032',
#        '103667517', '105959979', '108336203', '110798486', '113319950',
#        '115921723', '118615741', '121424797', '124336039', '127364044',
#        '130563107', '133953892', '137548613', '141258400', '145122851',
#        '149206663', '153459665', '157825609', '162323313', '167023385',
#        '171566640', '176054495', '180817312', '185720244', '190759952',
#        '195969722', '201392200', '206739024', '212172888', '217966101',
#        '223788766', '229675775', '235861484', '242200260', '248713095',
#        '255482918', '262397030', '269611898', '277160097', '284952322',
#        '292977949', '301265247', '309824829', '318601484', '327612838',
#        '336893835', '346475221', '356337762', '366489204', '376797999',
#        '387204553', '397855507', '408690375', '419778384', '431138704',
#        '442646825', '454306063', '466189102', '478185907', '490330870'],
#       dtype='object')

# %%
 cols = ['97256290', '99314028', '101445032',
       '103667517', '105959979', '108336203', '110798486', '113319950',
       '115921723', '118615741', '121424797', '124336039', '127364044',
       '130563107', '133953892', '137548613', '141258400', '145122851',
       '149206663', '153459665', '157825609', '162323313', '167023385',
       '171566640', '176054495', '180817312', '185720244', '190759952',
       '195969722', '201392200', '206739024', '212172888', '217966101',
       '223788766', '229675775', '235861484', '242200260', '248713095',
       '255482918', '262397030', '269611898', '277160097', '284952322',
       '292977949', '301265247', '309824829', '318601484', '327612838',
       '336893835', '346475221', '356337762', '366489204', '376797999',
       '387204553', '397855507', '408690375', '419778384', '431138704',
       '442646825', '454306063', '466189102', '478185907', '490330870']

# %%
for i in cols:
        fig = plt.figure(figsize=(5,5))
        plt.hist(df[i],color='#B22222',bins=10)
        plt.xlabel(i)
        plt.show()

# %%
years = df.columns[1:]

total_values = df[years].sum()

plt.figure(figsize=(30, 30))
plt.barh(years, total_values,color='#191970')
plt.xlabel('Total Values')
plt.ylabel('Year', size=20)
plt.title('Total Values per Year', size=20)
plt.show()

# %%
country_by_97256290 = df.sort_values(by='97256290').head(20)
country_by_97256290
# Out:
#     Africa Western and Central  97256290  99314028  101445032  103667517  \
# 221  Sint Maarten (Dutch part)    2646.0    2888.0     3171.0     3481.0
# 143   St. Martin (French part)    4135.0    4258.0     4388.0     4524.0
# 175                      Nauru    4582.0    4753.0     4950.0     5198.0
# 241                     Tuvalu    5404.0    5436.0     5471.0     5503.0
# 224   Turks and Caicos Islands    5604.0    5625.0     5633.0     5634.0
# 251     British Virgin Islands    7850.0    7885.0     7902.0     7919.0
# 48              Cayman Islands    8473.0    8626.0     8799.0     8985.0
# 160   Northern Mariana Islands    8702.0    8965.0     9252.0     9561.0
# 2                      Andorra    9443.0   10216.0    11014.0    11839.0
# 184                      Palau    9446.0    9639.0     9851.0    10076.0
# 151           Marshall Islands   15374.0   15867.0    16387.0    16947.0
# 208                 San Marino   15556.0   15895.0    16242.0    16583.0
# ...

# %%
country_by_97256290_t = country_by_97256290.set_index('Africa Western and Central').T
for country_name, data_values in country_by_97256290_t.iterrows():
    fig = plt.figure(figsize=(10, 5))
    sns.barplot(x=data_values.index, y=data_values.values)
country_by_97256290_t = country_by_97256290.set_index('Africa Western and Central').T
for country_name, data_values in country_by_97256290_t.iterrows():
    fig = plt.figure(figsize=(10, 5))
    sns.barplot(x=data_values.index, y=data_values.values)
    plt.xlabel('Countries')
    plt.ylabel('Data Values')
    plt.title(f"{country_name} - Data Values from 97256290 to 490330870")
    plt.xticks(rotation=90)
    plt.show()
